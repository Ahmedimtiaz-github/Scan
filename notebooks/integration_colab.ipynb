# %% [markdown]
# # AI Room Scan - Integration Demo (Colab)
#
# Run all cells for a full Quality preset demo. Outputs saved to `outputs/colab_run/`.

# %%
# Cell 1: Install dependencies
# !pip install -q torch torchvision diffusers transformers accelerate safetensors
# !pip install -q ultralytics opencv-python-headless pillow jsonschema
# !pip install -q git+https://github.com/facebookresearch/segment-anything.git
print("Dependencies installed.")

# %%
# Cell 2: Clone repo and upload sample (or use existing)
import os
if not os.path.exists("Scan"):
    # !git clone https://github.com/Ahmedimtiaz-github/Scan.git
    # %cd Scan
else:
    # %cd Scan
# Create sample if missing
os.makedirs("sample_data", exist_ok=True)
if not os.path.exists("sample_data/sample.jpg"):
    from PIL import Image
    Image.new("RGB", (512, 512), (128, 128, 128)).save("sample_data/sample.jpg")
print("Ready.")

# %%
# Cell 3: Run pipeline (Quality preset)
# !python -m src.main --mode image --preset quality --input sample_data/sample.jpg --output outputs/colab_run

# %%
# Cell 4: Validate and show outputs
# !python scripts/validate_end_to_end.py outputs/colab_run
# !ls -la outputs/colab_run/
